# %%
import pandas as pd
forbes = pd.read_csv("sentiment_data_fool.csv")
motley = pd.read_csv("sentiment_data_forbes.csv")

# %%
print(forbes.head())
print(forbes.shape[0])
print(motley.head())
print(motley.shape[0])
# Out:
#                                                  url        date  \
# 0  https://www.fool.com/investing/2024/06/06/wher...  2024-06-06
# 1  https://www.fool.com/investing/2025/01/19/jens...  2025-01-19
# 2  https://www.fool.com/investing/2023/12/16/can-...  2023-12-16
# 3  https://www.fool.com/investing/2023/07/25/taiw...  2023-07-25
# 4  https://www.fool.com/earnings/call-transcripts...  2022-11-17
#
#                                            case_text     label     score  \
# 0  Making the world smarter, happier, and richer....   neutral  0.910637
# 1  Nvidia saw the autonomous driving revolution c...  negative  0.747434
# 2                     © 1995 - 2025 The Motley Fool.   neutral  0.867397
# 3  And while demand may be improving somewhat fro...  negative  0.915828
# 4  Operator Your next question comes from the lin...   neutral  0.939469
#
#    score_positive  score_neutral  score_negative  numeric_label
# 0        0.063812       0.910637        0.025552              0
# 1        0.017242       0.235324        0.747434             -1
# 2        0.028308       0.867397        0.104295              0
# 3        0.041912       0.042260        0.915828             -1
# 4        0.030892       0.939469        0.029639              0
# 4494
#                                                  url        date  \
# 0  https://www.forbes.com/councils/forbesbusiness...  2022-04-19
# 1  https://www.forbes.com/sites/karlfreund/2022/0...  2022-01-10
# 2  https://www.forbes.com/sites/greatspeculations...  2024-07-09
# 3  https://www.forbes.com/sites/petercohan/2024/0...  2024-06-09
# 4  https://www.forbes.com/sites/rahulrazdan/2022/...  2022-03-02
#
#                                            case_text     label     score  \
# 0  However, when we look around at our cities tod...  positive  0.936959
# 1  So, yeah, they got that, too. While this is no...  positive  0.802355
# 2  Given the current uncertain macroeconomic envi...  negative  0.390987
# 3  In the meantime, business and political leader...  negative  0.959502
# 4  Getting past the machinery, the thought proces...   neutral  0.913600
#
#    numeric_label  positive_prob  neutral_prob  negative_prob
# 0              1       0.936959      0.046929       0.016112
# 1              1       0.802355      0.189667       0.007978
# 2             -1       0.318801      0.290212       0.390987
# 3             -1       0.019230      0.021268       0.959502
# 4              0       0.061657      0.913600       0.024743
# 1047

# %%
combined_df = pd.concat([forbes, motley], axis=0, ignore_index=True)
print(combined_df.shape[0])
# Out:
# 5541

# %%
print(combined_df.isna().sum())
# Out:
# url                  0
# date                 0
# case_text            0
# label                0
# score                0
# score_positive    1047
# score_neutral     1047
# score_negative    1047
# numeric_label        0
# positive_prob     4494
# neutral_prob      4494
# negative_prob     4494
# dtype: int64

# %%
# Combine each pair of columns: use values from 'score_*' when 'positive_prob', etc. are missing
combined_df['positive_prob'] = combined_df['positive_prob'].combine_first(combined_df['score_positive'])
combined_df['neutral_prob'] = combined_df['neutral_prob'].combine_first(combined_df['score_neutral'])
combined_df['negative_prob'] = combined_df['negative_prob'].combine_first(combined_df['score_negative'])

# Optionally drop the misnamed columns once combined
combined_df.drop(columns=['score_positive', 'score_neutral', 'score_negative'], inplace=True)

# Check for any remaining missing values
print(combined_df.isna().sum())
# Out:
# url              0
# date             0
# case_text        0
# label            0
# score            0
# 1544          https://www.fool.com/terms/s/stock-split/  2024-10-23
# 2218  https://www.fool.com/investing/2024/11/29/wher...  2024-11-29
# 1669  https://www.fool.com/investing/2024/12/15/afte...  2024-12-15
# 2598  https://www.fool.com/investing/2023/08/10/jens...  2023-08-10
# 1268  https://www.fool.com/earnings/call-transcripts...  2023-11-22
# 1039  https://www.fool.com/investing/2024/05/12/is-n...  2024-05-12
# 1779  https://www.fool.com/earnings/call-transcripts...  2022-11-17
# 422   https://www.fool.com/investing/stock-market/ma...  2023-07-03
# 4732  https://www.forbes.com/sites/jonmarkman/2022/0...  2022-01-24
#
#                                               case_text     label     score  \
# 5286  The release of developer platforms like Nvidia...  positive  0.641291
# 2559  Management noted that it approved 40% fewer lo...  negative  0.611616
# 4546  Lack of transparency  DeepSeek clamming up on ...  negative  0.514934
# 230   It's still the early days of the AI revolution...  negative  0.834552
# 1315  And so, 3D graphics is now not just for video ...   neutral  0.926565
# 4255  The company has a top-notch financial profile ...   neutral  0.523581
# 1345  The chip-making juggernaut just reported an in...  positive  0.930291
# 2569                     © 1995 - 2025 The Motley Fool.   neutral  0.867397
# 1129  That bodes well for Johnson Controls' upcoming...  negative  0.836889
# 381   So far, 100,000 developers are using the platf...  negative  0.973837
# 3562  Jensen Huang -- President and Chief Executive ...  positive  0.849026
# 1632  The company started out with a vision to deliv...   neutral  0.672220
# 4168  Few companies achieve that level of dominance,...  positive  0.696450
# 4596  The B200 GPU chipset due in Q1 of next year wi...  positive  0.951692
# 5135  “There was the big boom moment that took place...   neutral  0.926249
# 5364  For autonomous platforms, compute power and se...  positive  0.539873
# 439   Such high demand has done wonders for Nvidia's...  positive  0.951206
# 1033  The company was founded by Wei Li Dai, Pantas ...   neutral  0.953780
# 2527  The partnership with ViaCyte will likely tie C...  positive  0.716376
# 373   DeepSeek R1's emergence has had a rapid radica...  positive  0.516515
# 5374  The second quarter earnings season was expecte...  negative  0.971662
# 751   It may only lead to faster innovation in AI, a...  negative  0.926840
# 4331  So, both of these things are the drivers of th...   neutral  0.909589
# 4617  Note, too, that other estimates predict a stee...  positive  0.857208
# 576   NVDA data by YCharts That's exactly what happe...  negative  0.966112
# 4841  It not only overcomes physical boundaries but ...   neutral  0.564797
# 3413  The chart above shows Microsoft's price-to-ear...  negative  0.937193
# 1253  Those looking for a lower risk may gravitate t...   neutral  0.921381
# 23    The development of 5G mobile networks, however...  positive  0.920614
# 1101  The dramatic fall has lessened the enthusiasm ...  negative  0.805456
# 3904  That's nearly 65% above the current share pric...  negative  0.699385
# 3734  The company told investors it expects to show ...  negative  0.835011
# 4524  Representation of cryptocurrencies are seen in...   neutral  0.606170
# 1513  Amid such conditions, investors have turned on...  negative  0.973160
# 2698  We saw this in 2018 when a pause in data cente...  negative  0.908783
# 1647  Image source: Getty Images. Still, that lower ...  negative  0.492751
# 2650  The Motley Fool reaches millions of people eve...   neutral  0.878006
# 3127  The company claims that the new chip is "nearl...  positive  0.936245
# 1533  Meta is facing multiple headwinds such as chan...  negative  0.972081
# 4728  Growth potential Arm historically did well in ...   neutral  0.588659
# 319   If these scenarios play out, then Nvidia would...  negative  0.920029
# 1544  The main benefit of a stock split is to make a...   neutral  0.896583
# 2218  That explains why analysts have raised their g...  positive  0.915922
# 1669  This is heavily demonstrated by how quickly Nv...  negative  0.577308
# 2598  Market data powered by Xignite and Polygon.io....   neutral  0.937931
# 1268  In the case of many companies, we create tools...   neutral  0.934860
# 1039  The upside is much higher if Nvidia maintains ...  positive  0.932016
# 1779  We are quickly adapting to the macro environment.  positive  0.732678
# 422   Editas plans to report results from the study ...   neutral  0.922692
# 4732  The stock has fallen from a high of $730 in ea...  negative  0.973463
#
#       numeric_label  positive_prob  neutral_prob  negative_prob
# 5286              1       0.641291      0.349119       0.009590
# 2559             -1       0.327680      0.060704       0.611616
# 4546             -1       0.130050      0.355016       0.514934
# 230              -1       0.019342      0.146106       0.834552
# 1315              0       0.056405      0.926565       0.017030
# 4255              0       0.457144      0.523581       0.019275
# 1345              1       0.930291      0.050743       0.018966
# 2569              0       0.028308      0.867397       0.104295
# 1129             -1       0.126521      0.036590       0.836889
# 381              -1       0.007634      0.018529       0.973837
# 3562              1       0.849026      0.141040       0.009934
# 1632              0       0.318878      0.672220       0.008902
# 4168              1       0.696450      0.265929       0.037621
# 4596              1       0.951692      0.034236       0.014072
# 5135              0       0.046109      0.926249       0.027643
# 5364              1       0.539873      0.449930       0.010197
# 439               1       0.951206      0.028511       0.020283
# 1033              0       0.021695      0.953780       0.024524
# 2527              1       0.716376      0.276644       0.006980
# 373               1       0.516515      0.124244       0.359241
# 5374             -1       0.009137      0.019201       0.971662
# 751              -1       0.020490      0.052670       0.926840
# 4331              0       0.062590      0.909589       0.027821
# 4617              1       0.857208      0.056152       0.086640
# 576              -1       0.009500      0.024387       0.966112
# 4841              0       0.032754      0.564797       0.402449
# 3413             -1       0.025341      0.037465       0.937193
# 1253              0       0.064579      0.921381       0.014039
# 23                1       0.920614      0.065968       0.013418
# 1101             -1       0.168298      0.026246       0.805456
# 3904             -1       0.186423      0.114192       0.699385
# 3734             -1       0.121771      0.043217       0.835011
# 4524              0       0.385231      0.606170       0.008599
# 1513             -1       0.010255      0.016586       0.973160
# 2698             -1       0.052481      0.038736       0.908783
# 1647             -1       0.458070      0.049179       0.492751
# 2650              0       0.110119      0.878006       0.011875
# 3127              1       0.936245      0.052089       0.011666
# 1533             -1       0.010684      0.017235       0.972081
# 4728              0       0.318186      0.588659       0.093155
# 319              -1       0.009821      0.070150       0.920029
# 1544              0       0.089950      0.896583       0.013467
# 2218              1       0.915922      0.053698       0.030380
# 1669             -1       0.215701      0.206991       0.577308
# 2598              0       0.030255      0.937931       0.031814
# 1268              0       0.043119      0.934860       0.022021
# 1039              1       0.932016      0.041954       0.026030
# 1779              1       0.732678      0.257000       0.010322
# 422               0       0.065288      0.922692       0.012020
# 4732             -1       0.008972      0.017565       0.973463

# %%
combined_df.to_csv("sentiment_data.csv", index=False)
print("Files saved:\n- main file as sentiment.csv (test-ready dataset)")
# Out:
# Files saved:
# - FullSet/full_set.csv (full dataset)
